# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append("../")

# %%
from src.sequential_dataset import SequentialLegoDataJointGraph

ds = SequentialLegoDataJointGraph("../data", 100)
# Out:
# Processing...
# Processing Data...
#  25%|██▌       | 1/4 [00:00<00:00,  8.81it/s]
# n: 1
# m: 200
# m,n: 1 200
# n: 2
# m: 200
# m,n: 2 200
# n: 3
# m: 200
# m,n: 3 200
# n: 4
# m: 200
# m,n: 4 200
# n: 5
# m: 200
# m,n: 5 200
# n: 6
# m: 200
# m,n: 6 200
# n: 7
# m: 200
# m,n: 7 200
# n: 8
# m: 200
# m,n: 8 200
# n: 9
# m: 200
# m,n: 9 200
# n: 10
# m: 200
# m,n: 10 200
# n: 11
# m: 200
# m,n: 11 200
# n: 12
# m: 200
# m,n: 12 200
# n: 13
# m: 200
# m,n: 13 200
# n: 14
# m: 200
# m,n: 14 200
# n: 1
# m: 200
# m,n: 1 200
# n: 2
# m: 200
# m,n: 2 200
# n: 3
# m: 200
# m,n: 3 200
# n: 4
# m: 200
# m,n: 4 200
# n: 5
# m: 200
# m,n: 5 200
# n: 6
# m: 200
# m,n: 6 200
# n: 7
# m: 200
# m,n: 7 200
# n: 8
# m: 200
# m,n: 8 200
# n: 9
# m: 200
# m,n: 9 200
# n: 10
# m: 200
# m,n: 10 200
# n: 11
# m: 200
# m,n: 11 200
# n: 12
# m: 200
# m,n: 12 200
# n: 13
# m: 200
# m,n: 13 200
# n: 14
# m: 200
# m,n: 14 200
# n: 15
# m: 200
# m,n: 15 200
# n: 16
# m: 200
# m,n: 16 200
# n: 17
# m: 200
# ...

# %%
ds[3]
# Out:
# HeteroData(
#   lego={
#     x=[4, 2],
#     y=[1, 6],
#     edge_index=[2, 3],
#     edge_attr=[3, 2],
#     pos=[4, 6]
#   },
#   points={
#     pos=[200, 3],
#     edge_index=[2, 1200]
#   },
#   (lego, to, points)={ edge_index=[2, 800] }
# )
